# %%
def fun(n):
    if n<=1:
        return 1
    else:
        return n*fun(n-1)
    
fun(1)
# Out:
# 1

# %%
def fun(n):
    if n==1:

        return 
    
    else:
        
        return fun(n-1)
    
fun(10)

# %%
# using recurssion convert the given decimal to binary
