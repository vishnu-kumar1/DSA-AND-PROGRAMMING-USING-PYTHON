# %%
# 1. Factorial of given number
def fun(n):
    if n<=1:
        return 1
    else:
        return n*fun(n-1)
    
fun(4)
# Out:
# 24

# %%
def fun(n):
    if n==1:

        return 
    
    else:
        
        return fun(n-1)
    
fun(10)

# %%
#
